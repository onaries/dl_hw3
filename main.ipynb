# %%
import numpy as np
import tensorflow as tf

# %%
# variables

batch_size = 128
num_classes = 7
epochs = 100

# %%
# dataset loading

dataset_file = 'dataset/fer2013/fer2013.csv'
data = np.genfromtxt(dataset_file, dtype=None, delimiter=',', skip_header=1)

# %%
labels = []
images = []
usages = []

x_train = []
y_train = []
x_test1 = []
y_test1 = []
x_test2 = []
y_test2 = []

# %%
def labeling(data):
    label = np.zeros(7, dtype=np.uint8)
    if data == 0:
        label[0] = 1
    elif data == 1:
        label[1] = 1
    elif data == 2:
        label[2] = 1
    elif data == 3:
        label[3] = 1
    elif data == 4:
        label[4] = 1
    elif data == 5:
        label[5] = 1
    elif data == 6:
        label[6] = 1
    
    return label.tolist()

# %%
for i in range(len(data)):
    if data[i][2] == b'Training':
        x_train.append(data[i][1].split(sep=b' '))
        y_train.append(labeling(data[i][0]))
    elif data[i][2] == b'PublicTest':
        x_test1.append(data[i][1].split(sep=b' '))
        y_test1.append(labeling(data[i][0]))
    else:
        x_test2.append(data[i][1].split(sep=b' '))
        y_test2.append(labeling(data[i][0]))

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test1 = np.array(x_test1)
y_test1 = np.array(y_test1)
x_test2 = np.array(x_test2)
y_test2 = np.array(y_test2)

# %%
x_train.shape[0]
# Out:
# 28709

# %%
x_train = x_train.reshape(x_train.shape[0], 48, 48, 1)
x_test1 = x_test1.reshape(x_test1.shape[0], 48, 48, 1)
x_test2 = x_test2.reshape(x_test1.shape[0], 48, 48, 1)

# %%
print(x_train.shape)
print(x_test1.shape)
print(x_test2.shape)
# Out:
# (28709, 48, 48, 1)
# (3589, 48, 48, 1)
# (3589, 48, 48, 1)

# %%
model = tf.contrib.keras.models.Sequential()

# %%
x_train.shape[0:]
# Out:
# (28709, 48, 48, 1)

# %%
model.add(tf.contrib.keras.layers.Conv2D(64, (3, 3), padding='same', input_shape=(48, 48, 1)))
model.add(tf.contrib.keras.layers.Activation('relu'))

# %%
model.add(tf.contrib.keras.layers.Conv2D(64, (3, 3)))
model.add(tf.contrib.keras.layers.Activation('relu'))

# %%
model.add(tf.contrib.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.contrib.keras.layers.Dropout(0.25))

# %%
model.add(tf.contrib.keras.layers.Conv2D(128, (3, 3), padding='same'))
model.add(tf.contrib.keras.layers.Activation('relu'))

# %%
model.add(tf.contrib.keras.layers.Conv2D(128, (3, 3)))
model.add(tf.contrib.keras.layers.Activation('relu'))

# %%
model.add(tf.contrib.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.contrib.keras.layers.Dropout(0.25))

# %%
model.add(tf.contrib.keras.layers.Flatten())
model.add(tf.contrib.keras.layers.Dense(512))
model.add(tf.contrib.keras.layers.Activation('relu'))
model.add(tf.contrib.keras.layers.Dropout(0.5))
model.add(tf.contrib.keras.layers.Dense(num_classes))
model.add(tf.contrib.keras.layers.Activation('softmax'))

# %%
# optimizer

opt = tf.contrib.keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
early_stopping = tf.contrib.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# %%
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test1, y_test1), shuffle=True, callbacks=[early_stopping])
# Out:
# Train on 28709 samples, validate on 3589 samples
# Epoch 1/100
# 28709/28709 [==============================] - 36s - loss: 4.2770 - acc: 0.2267 - val_loss: 1.7651 - val_acc: 0.3670
# Epoch 2/100
# 28709/28709 [==============================] - 35s - loss: 1.6592 - acc: 0.3523 - val_loss: 1.5799 - val_acc: 0.4110
# Epoch 3/100
# 28709/28709 [==============================] - 35s - loss: 1.5413 - acc: 0.4075 - val_loss: 1.4651 - val_acc: 0.4567
# Epoch 4/100
# 28709/28709 [==============================] - 34s - loss: 1.4538 - acc: 0.4468 - val_loss: 1.4110 - val_acc: 0.4756
# Epoch 5/100
# 28709/28709 [==============================] - 35s - loss: 1.3966 - acc: 0.4696 - val_loss: 1.3792 - val_acc: 0.4765
# Epoch 6/100
# 28709/28709 [==============================] - 34s - loss: 1.3363 - acc: 0.4953 - val_loss: 1.3441 - val_acc: 0.4990
# Epoch 7/100
# 28709/28709 [==============================] - 34s - loss: 1.2852 - acc: 0.5139 - val_loss: 1.3165 - val_acc: 0.5079
# Epoch 8/100
# 28709/28709 [==============================] - 34s - loss: 1.2460 - acc: 0.5295 - val_loss: 1.3103 - val_acc: 0.5099
# Epoch 9/100
# 28709/28709 [==============================] - 34s - loss: 1.2022 - acc: 0.5513 - val_loss: 1.2458 - val_acc: 0.5322
# Epoch 10/100
# 28709/28709 [==============================] - 35s - loss: 1.1604 - acc: 0.5689 - val_loss: 1.2381 - val_acc: 0.5394
# Epoch 11/100
# 28709/28709 [==============================] - 34s - loss: 1.1292 - acc: 0.5800 - val_loss: 1.2165 - val_acc: 0.5503
# Epoch 12/100
# 28709/28709 [==============================] - 34s - loss: 1.0971 - acc: 0.5942 - val_loss: 1.2580 - val_acc: 0.5389
# Epoch 13/100
# 28709/28709 [==============================] - 34s - loss: 1.0616 - acc: 0.6095 - val_loss: 1.2717 - val_acc: 0.5534
# Epoch 14/100
# 28709/28709 [==============================] - 35s - loss: 1.0335 - acc: 0.6209 - val_loss: 1.1901 - val_acc: 0.5626
# Epoch 15/100
# 28709/28709 [==============================] - 35s - loss: 0.9959 - acc: 0.6407 - val_loss: 1.1870 - val_acc: 0.5612
# Epoch 16/100
# 28709/28709 [==============================] - 35s - loss: 0.9601 - acc: 0.6516 - val_loss: 1.2363 - val_acc: 0.5665
# Epoch 17/100
# 28709/28709 [==============================] - 35s - loss: 0.9305 - acc: 0.6612 - val_loss: 1.2069 - val_acc: 0.5723
# Epoch 18/100
# 28709/28709 [==============================] - 34s - loss: 0.9058 - acc: 0.6757 - val_loss: 1.2882 - val_acc: 0.5751
# Epoch 19/100
# 28709/28709 [==============================] - 34s - loss: 0.8817 - acc: 0.6809 - val_loss: 1.2120 - val_acc: 0.5790
# Epoch 20/100
# 28709/28709 [==============================] - 35s - loss: 0.8433 - acc: 0.6981 - val_loss: 1.2643 - val_acc: 0.5743
# Epoch 21/100
# 28709/28709 [==============================] - 35s - loss: 0.8268 - acc: 0.7013 - val_loss: 1.2365 - val_acc: 0.5834
# Epoch 22/100
# 28709/28709 [==============================] - 34s - loss: 0.8020 - acc: 0.7109 - val_loss: 1.2100 - val_acc: 0.5921
# Epoch 23/100
# 28709/28709 [==============================] - 35s - loss: 0.7691 - acc: 0.7273 - val_loss: 1.1794 - val_acc: 0.5826
# Epoch 24/100
# 28709/28709 [==============================] - 35s - loss: 0.7554 - acc: 0.7315 - val_loss: 1.3587 - val_acc: 0.5851
# Epoch 25/100
# 28709/28709 [==============================] - 34s - loss: 0.7280 - acc: 0.7418 - val_loss: 1.3245 - val_acc: 0.5818
# Epoch 26/100
# 28709/28709 [==============================] - 35s - loss: 0.7137 - acc: 0.7462 - val_loss: 1.3808 - val_acc: 0.5874
# Epoch 27/100
# 28709/28709 [==============================] - 34s - loss: 0.6799 - acc: 0.7583 - val_loss: 1.4957 - val_acc: 0.5826
# Epoch 28/100
# 28709/28709 [==============================] - 35s - loss: 0.6722 - acc: 0.7633 - val_loss: 1.6012 - val_acc: 0.5773
# Epoch 29/100
# 28709/28709 [==============================] - 34s - loss: 0.6521 - acc: 0.7683 - val_loss: 1.3473 - val_acc: 0.5968
# Epoch 30/100
# 28709/28709 [==============================] - 35s - loss: 0.6276 - acc: 0.7773 - val_loss: 1.4837 - val_acc: 0.5935
# Epoch 31/100
# 28709/28709 [==============================] - 34s - loss: 0.6182 - acc: 0.7833 - val_loss: 1.4521 - val_acc: 0.5960
# Epoch 32/100
# 28709/28709 [==============================] - 35s - loss: 0.5950 - acc: 0.7932 - val_loss: 1.5263 - val_acc: 0.5887
# Epoch 33/100
# 28709/28709 [==============================] - 35s - loss: 0.5875 - acc: 0.7932 - val_loss: 1.6093 - val_acc: 0.5932
# Epoch 34/100
# 28709/28709 [==============================] - 35s - loss: 0.5728 - acc: 0.8005 - val_loss: 1.8291 - val_acc: 0.5882

# %%
import matplotlib.pyplot as plt

# %%
emotion = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

# %%
im = np.array(x_test1[0], dtype=np.uint8)

# %%
im = im.reshape(48, 48)

# %%
plt.imshow(im, cmap='gray')
plt.show()

# %%
model.save('model.h5')

# %%
model.save_weights('model_weights.h5')

# %%
pred = model.predict_classes(x_test1, batch_size=1)
# Out:
# 3582/3589 [============================>.] - ETA: 0s

# %%
len(pred)
# Out:
# 3589

# %%
pred[:100]
# Out:
# array([0, 0, 0, 6, 3, 3, 2, 4, 2, 2, 4, 0, 2, 2, 6, 2, 5, 5, 5, 3, 0, 5, 4,
#        6, 6, 0, 4, 4, 0, 5, 3, 6, 3, 6, 0, 0, 2, 2, 4, 3, 0, 4, 3, 3, 6, 3,
#        5, 3, 5, 6, 0, 3, 5, 2, 4, 3, 2, 4, 5, 3, 6, 3, 4, 3, 5, 3, 6, 6, 0,
#        3, 4, 5, 6, 3, 2, 6, 5, 6, 6, 4, 0, 0, 0, 4, 5, 4, 3, 3, 5, 3, 6, 0,
#        6, 0, 0, 0, 2, 3, 3, 0])

# %%
accu = model.evaluate(x_test1, y_test1, batch_size=128)
# Out:
# 3584/3589 [============================>.] - ETA: 0s

# %%
accu
# Out:
# [1.8290669353402202, 0.58818612427690231]

# %%
accu2 = model.evaluate(x_test2, y_test2, batch_size=128)
# Out:
# 3584/3589 [============================>.] - ETA: 0s

# %%
accu2
# Out:
# [1.7744717528209544, 0.59152967403711598]

# %%
im = np.array(x_test1[1], dtype=np.uint8)
im = im.reshape(48, 48)
print(y_test1[1])
# Out:
# [0 1 0 0 0 0 0]

# %%
plt.imshow(im, cmap='gray')
plt.xlabel(emotion[pred[1]])
plt.show()

# %%
im = np.array(x_test1[2], dtype=np.uint8)
im = im.reshape(48, 48)
print(y_test1[2])
# Out:
# [0 0 0 0 1 0 0]

# %%
plt.imshow(im, cmap='gray')
plt.xlabel(emotion[pred[2]])
plt.show()

# %%
im = np.array(x_test1[3], dtype=np.uint8)
im = im.reshape(48, 48)
print(y_test1[3])
# Out:
# [0 0 0 0 0 0 1]

# %%
plt.imshow(im, cmap='gray')
plt.xlabel(emotion[pred[3]])
plt.show()

# %%
im = np.array(x_test1[4], dtype=np.uint8)
im = im.reshape(48, 48)

# %%
plt.imshow(im, cmap='gray')
plt.xlabel(emotion[pred[4]])
plt.show()
print(y_test1[4])
# Out:
# [0 0 0 1 0 0 0]
